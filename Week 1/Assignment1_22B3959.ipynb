# %% [markdown]
# Import necessary packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# TODO 1: Read the data from ```data.csv``` using ```pandas```

# %%
df = pd.read_csv('data.csv')
X = df['X'].to_numpy().reshape(-1,1)
y = df['y'].to_numpy().reshape(-1,1)

# %% [markdown]
# TODO 2: Complete the ```normalize``` function. For a numpy array X, normalized output will be
# ```(X - mean(X))/standard_devaiation(X)```

# %%
def normalize(X):
    avg = np.mean(X)
    dev = np.std(X)
    return (X-avg)/dev

X_norm = normalize(X)
y_norm = normalize(y)

# Initialize parameters
theta = np.random.randn(2, 1)  # We have 2 parameters (theta_0 and theta_1)

# %% [markdown]
# TODO 3: Complete the function ```complete_cost``` function below. Refer to Problem statement for the cost (error) function for linear regression.
#
# Here, ```X``` : np.array of x-coordinates of points
#
# ```y``` : np.array of y-coordinates of points
#
# ```theta``` : np.array of parameters

# %%
def compute_cost(X, y, theta):
    m = len(y)
    X_b = np.c_[np.ones((m, 1)), X]  # Add bias term (x0 = 1)
    h = X_b.dot(theta)
    
    error = h -y
    sq_error = error**2
    cost = np.sum(sq_error)/(2*m)
    
    return cost

# %% [markdown]
# TODO 4: Implement Gradient Descent for linear regression according to algorithm given in the Problem Statement. Your only task is to update theta properly by finding the gradient correctly.

# %%
def gradient_descent(X, y, theta, learning_rate, iterations):
    m = len(y)
    X_b = np.c_[np.ones((m, 1)), X]  # Add bias term (x0 = 1)
    cost_history = []

    for _ in range(iterations):
       
        h = np.dot(X_b,theta)
        error = h -y
        gradient = np.dot(X_b.T,error) /m

        theta = theta - learning_rate*gradient
        cost = compute_cost(X, y, theta)
        cost_history.append(cost)

    return theta, cost_history

# %% [markdown]
# TODO 5: Find ```theta_optimal``` and ```cost_history``` by calling the ```gradient_descent``` function. Also, print them.

# %%
learning_rate = 0.1
iterations = 1000

theta_optimal,cost_history = gradient_descent(X_norm,y_norm,theta,learning_rate,iterations)
print(theta_optimal)
print(cost_history)
# Out:
# [[9.99431856e-16]
#  [8.77082403e-01]]
# [0.5218655440543958, 0.4446301042547254, 0.38206939801699247, 0.3313952259644289, 0.2903491466018522, 0.2571018223181652, 0.2301714896483786, 0.20835792018585164, 0.1906889289212047, 0.17637704599684065, 0.16478442082810585, 0.1553943944414306, 0.14778847306822368, 0.1416276767559261, 0.13663743174296497, 0.1325953332824665, 0.12932123352946273, 0.12666921272952972, 0.12452107588158398, 0.12278108503474788, 0.12137169244881064, 0.12023008445420151, 0.1193053819785681, 0.11855637297330505, 0.11794967567904198, 0.1174582508706889, 0.11706019677592287, 0.11673777295916243, 0.11647660966758645, 0.11626506740140988, 0.11609371816580692, 0.11595492528496848, 0.11584250305148937, 0.11575144104237124, 0.11567768081498558, 0.11561793503080323, 0.11556954094561546, 0.11553034173661343, 0.11549859037732174, 0.11547287177629549, 0.11545203970946424, 0.11543516573533093, 0.11542149781628293, 0.11541042680185402, 0.11540145928016664, 0.11539419558759986, 0.11